# %%
# %pylab inline
# !pwd
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/toddr/Software/pylabs/ipn

# %%
import matplotlib.pyplot as plt
import pylab
import pandas
from pylab import rcParams
rcParams['figure.figsize'] = 20, 15
matplotlib.rcParams.update({'font.size': 22})
import numpy as np
import scipy as sp
from scipy import stats
from scipy.stats import linregress
import string
from struct import unpack
import shutil
import fileinput
import math, decimal
from sys import argv
import os, glob
from os.path import join as pathjoin
from os.path import basename
from pylabs.utils.paths import getlocaldataroot
from pylabs.utils.timing import waitForFiles
from pylabs.utils.selection import select, withVoxelsOverThresholdOf
from IPython.display import display, HTML
# Out:
# /home/toddr/Software/anaconda2/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
fs = getlocaldataroot()
os.chdir(pathjoin(fs, 'phantom_qT1_slu'))
# !ls *.pickle
# Out:
# hello.pickle  J_sepcols_jmax32.pickle

# %%
jdata = pandas.read_pickle('J_sepcols_jmax32.pickle')
#jdata.plot(x=jdata[14],y=jdata[7])
jdata[14]
# Out:
#        mindiff 7.0 10.0 15.0 20.0 30.0
# 8    0.0426761  22   22   22   22   26
# 7   0.00738515   3    3    3    3    7
# 10  0.00439564   1    2    3    3   14
# 9   0.00552362   3    3    3    3    4
# 11  0.00340661   3    3    3    3    4
# 13   0.0438411   4    4    5    5    5
# 14   0.0604116   1    1   32   32   32
# 15   0.0283342  32   32   32   32   32
# 17  0.00851904   2    2    2    2   21
# 16  0.00433213   3    3    3    3    9
# 18  0.00832033   1    1    1    1   11
# 12     0.16156  32   32   32   32   32

# %%
jdata[14]
# Out:
#        mindiff 7.0 10.0 15.0 20.0 30.0
# 8    0.0426761  22   22   22   22   26
# 7   0.00738515   3    3    3    3    7
# 10  0.00439564   1    2    3    3   14
# 9   0.00552362   3    3    3    3    4
# 11  0.00340661   3    3    3    3    4
# 13   0.0438411   4    4    5    5    5
# 14   0.0604116   1    1   32   32   32
# 15   0.0283342  32   32   32   32   32
# 17  0.00851904   2    2    2    2   21
# 16  0.00433213   3    3    3    3    9
# 18  0.00832033   1    1    1    1   11
# 12     0.16156  32   32   32   32   32

# %%
jdata[14].iloc[:,1:].plot.bar()

# %%
jdata[28].iloc[:,1:].describe(percentiles=[0.25])
# Out:
#         7.0   10.0  15.0  20.0  30.0
# count     12    12    12    12    12
# unique     5     5     6     6     8
# top        4     4     4     4    32
# freq       4     4     3     3     3

# %%
fs = getlocaldataroot()
statsdir = fs+'self_control/hbm_group_data/qT1/tbss_qT1_reg_v7/stats/'
exptag='filter_skel_gender_and_qT1_delta_n500'                     # define 1st as orig n500 exptag to find mat file dir
matfiledir = pathjoin(statsdir,'matfiles','matfiles_'+exptag)
exptag='randpar_n5000_filtered_skel_gender_and_qT1_delta_fm_sig_n500_2col_qT1'    #results dir where n5000 plot files found
resultdir = pathjoin(statsdir,'randomise_runs',exptag)
plotfiledir = pathjoin(resultdir, 'plots')
atlasfile = 'mori1_atlas.nii.gz'
atlas = pathjoin('data','atlases',atlasfile)
atlasabbrev = str(os.path.basename(atlas).split('_')[0])
atlasregions = [str(r).zfill(5) for r in range(1,176)]                      #5digit integer reffering to absolute atlas region code from atlas LUT txt file
corrPfiles = [ '/media/DiskArray/shared_data/js/self_control/hbm_group_data/qT1/tbss_qT1_reg_v7/stats/randomise_runs/randpar_n5000_filtered_skel_gender_and_qT1_delta_fm_sig_n500_2col_qT1/randpar_n5000_all_qT1_skeletonised_filt_c2b02s16_Gender_c2b07s16d_BDSscore_tfce_corrp_tstat2.nii.gz' ]
selectedCorrPfiles = select(corrPfiles, withVoxelsOverThresholdOf(.95))
combs = deconstructFullRandparFiles(selectedCorrPfiles, matdir=None, imgdir=statsdir)
for key, value in combs.items():
    bhavcode =  str(value[0].split('.')[0])
    behavdescr = str(value[1])
    modality = str(value[3])
    tstat = str(value[4])
    for a in atlasregions:
        plotfiles = os.path.join(plotfiledir, 'plots_{0}_{1}_{2}_{3}_{4}.txt'.format(atlasabbrev, a, bhavcode, modality, tstat))
        plotfileslab = [plotfiles + 'l' ]
        if os.path.isfile(plotfiles):
            plotfile = fileinput.FileInput(files=plotfiles)
            lines = [l.strip().split("\n") for l in plotfile]
            fileinput.close()
            plotfilelab = fileinput.FileInput(files=plotfileslab)
            label = [lline.strip().split("\n") for lline in plotfilelab]
            fileinput.close()
            x = []
            y = []
            sid = []
            for line in lines:
                if line:
                    items = [l.split() for l in line]
                    y.append(float(items[0][0]))
                    x.append(float(items[0][1]))
                    sid.append(int(items[0][4]))
            x = np.array(x)
            y = np.array(y)
            sid = np.array(sid)
            slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
            line = slope*x+intercept
            if r_value > 0.7 or r_value < -0.75:
                atlasregid =  " ("+str(a.lstrip("0"))+")"
                fig, ax = plt.subplots()
                if opts.showsid:
                    for i, txt in enumerate(sid):
                        ax.annotate(txt, (x[i],y[i]))
                title_string = label[0][0]+atlasregid+"\nr="+str(round(decimal.Decimal(r_value),3)) \
                                +" p="+ str(round(decimal.Decimal(p_value),5))+" serr="+  \
                                str(round(decimal.Decimal(std_err),4))
                ax.set_title(title_string)
                ax.set_xlabel(modality)
                ax.set_ylabel(behavdescr)
                plt.xlim(int(np.min(x)-0.1*np.min(x)), np.max(x)+0.1*np.max(x))
                plt.ylim(np.min(y)-0.1*np.min(y), np.max(y)+0.1*np.max(y))
                ax.plot(x,line,'r-',x,y,'bx', markersize=30)
                show()
# Out:
# Found 42266 voxels over threshold in randpar_n5000_all_qT1_skeletonised_filt_c2b02s16_Gender_c2b07s16d_BDSscore_tfce_corrp_tstat2.nii.gz
