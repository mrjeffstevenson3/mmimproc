# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
from pathlib import *
from pylabs.utils.paths import getnetworkdataroot
fs = Path(getnetworkdataroot())
pd.set_option('display.width', 999999)
pd.options.display.max_colwidth = 200

# %%
vtkf = fs / 'bbc' / 'allvtk_motor_and_cc_combined_dec14_2016.csv'
vtk_fbs = pd.read_csv(vtkf)

# %%
#this renames col label 'subjectid' with 'vtk_file_name'
vtk_fbs.rename(columns={'subjectid': 'vtk_file_name', 'icountgood': 'FB_reach_dest', 'icounttotal': 'total_num_FB'}, inplace=True)
#makes subj id fm 1st 10 chars of vtk_file_name
vtk_fbs['Subjid'] = vtk_fbs['vtk_file_name'].str[0:10]
#makes fit methods
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('restore_cam_tensor_medfilt'), 'fit_method'] = 'restore_camino_mf'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('restore_cam_tensor_mori'), 'fit_method'] = 'restore_camino'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('wls_cam_tensor_medfilt'), 'fit_method'] = 'wls_camino_mf'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('wls_cam_tensor_mori'), 'fit_method'] = 'wls_camino'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('ols_cam_tensor_medfilt'), 'fit_method'] = 'ols_camino_mf'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('ols_cam_tensor_mori'), 'fit_method'] = 'ols_camino'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('ols_dipy_tensor_mori'), 'fit_method'] = 'ols_dipy'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('ols_dipy_tensor_med'), 'fit_method'] = 'ols_dipy_mf'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('wls_dipy_tensor_mori'), 'fit_method'] = 'wls_dipy'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('wls_dipy_tensor_medfilt'), 'fit_method'] = 'wls_dipy_mf'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('ols_fsl_tensor_medfilt'), 'fit_method'] = 'ols_fsl_mf'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('ols_fsl_tensor_mori'), 'fit_method'] = 'ols_fsl'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('wls_fsl_tensor_medfilt'), 'fit_method'] = 'wls_fsl_mf'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('wls_fsl_tensor_mori'), 'fit_method'] = 'wls_fsl'
#makes region names for regions col.
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('LeftPostIntCap'), 'region'] = 'LeftPostIntCap'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('RightPostIntCap'), 'region'] = 'RightPostIntCap'
vtk_fbs.loc[vtk_fbs['vtk_file_name'].str.contains('mori_CC'), 'region'] = 'Corpus_Callosum'

# %%
vtk_fbs.ix[31:90,['Subjid', 'fit_method', 'region', 'vtk_file_name', 'FB_reach_dest', 'total_num_FB', 'tot-arrived', '%arrived']]
# Out:
#         Subjid      fit_method           region                                                                                                             vtk_file_name  FB_reach_dest  total_num_FB  tot-arrived   %arrived
# 31  sub-bbc105             NaN  RightPostIntCap          sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_mori_RightPostIntCap-123.vtk            225           384          159  41.406250
# 32  sub-bbc105     wls_dipy_mf   LeftPostIntCap           sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_dipy_tensor_medfilt_mori_LeftPostIntCap-35.vtk            203           418          215  51.435407
# 33  sub-bbc105     wls_dipy_mf  RightPostIntCap         sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_dipy_tensor_medfilt_mori_RightPostIntCap-123.vtk            355           397           42  10.579345
# 34  sub-bbc105        wls_dipy   LeftPostIntCap                   sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_dipy_tensor_mori_LeftPostIntCap-35.vtk            126           408          282  69.117647
# 35  sub-bbc105        wls_dipy  RightPostIntCap                 sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_dipy_tensor_mori_RightPostIntCap-123.vtk            239           385          146  37.922078
# 36  sub-bbc105      wls_fsl_mf   LeftPostIntCap            sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            203           415          212  51.084337
# 37  sub-bbc105      wls_fsl_mf  RightPostIntCap          sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            349           395           46  11.645570
# 38  sub-bbc105         wls_fsl   LeftPostIntCap                    sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_mori_LeftPostIntCap-35.vtk            118           406          288  70.935961
# 39  sub-bbc105         wls_fsl  RightPostIntCap                  sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_mori_RightPostIntCap-123.vtk            232           378          146  38.624339
# 40  sub-bbc106     ols_dipy_mf   LeftPostIntCap           sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_medfilt_mori_LeftPostIntCap-35.vtk            248           458          210  45.851528
# 41  sub-bbc106     ols_dipy_mf  RightPostIntCap         sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_medfilt_mori_RightPostIntCap-123.vtk            295           418          123  29.425837
# 42  sub-bbc106        ols_dipy   LeftPostIntCap                   sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_mori_LeftPostIntCap-35.vtk            154           446          292  65.470852
# 43  sub-bbc106        ols_dipy  RightPostIntCap                 sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_mori_RightPostIntCap-123.vtk            197           413          216  52.300242
# 44  sub-bbc106      ols_fsl_mf   LeftPostIntCap            sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            236           458          222  48.471616
# 45  sub-bbc106      ols_fsl_mf  RightPostIntCap          sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            284           418          134  32.057416
# 46  sub-bbc106         ols_fsl   LeftPostIntCap                    sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_mori_LeftPostIntCap-35.vtk            126           448          322  71.875000
# 47  sub-bbc106         ols_fsl  RightPostIntCap                  sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_mori_RightPostIntCap-123.vtk            187           410          223  54.390244
# 48  sub-bbc106  restore_camino   LeftPostIntCap    sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            235           458          223  48.689956
# 49  sub-bbc106  restore_camino  RightPostIntCap  sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            268           418          150  35.885167
# 50  sub-bbc106             NaN   LeftPostIntCap            sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_mori_LeftPostIntCap-35.vtk            138           447          309  69.127517
# 51  sub-bbc106             NaN  RightPostIntCap          sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_mori_RightPostIntCap-123.vtk            168           406          238  58.620690
# 52  sub-bbc106     wls_dipy_mf   LeftPostIntCap           sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_dipy_tensor_medfilt_mori_LeftPostIntCap-35.vtk            239           457          218  47.702407
# 53  sub-bbc106     wls_dipy_mf  RightPostIntCap         sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_dipy_tensor_medfilt_mori_RightPostIntCap-123.vtk            299           418          119  28.468900
# 54  sub-bbc106        wls_dipy   LeftPostIntCap                   sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_dipy_tensor_mori_LeftPostIntCap-35.vtk            134           447          313  70.022371
# 55  sub-bbc106        wls_dipy  RightPostIntCap                 sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_dipy_tensor_mori_RightPostIntCap-123.vtk            196           410          214  52.195122
# 56  sub-bbc106      wls_fsl_mf   LeftPostIntCap            sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            236           458          222  48.471616
# 57  sub-bbc106      wls_fsl_mf  RightPostIntCap          sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            284           418          134  32.057416
# 58  sub-bbc106         wls_fsl   LeftPostIntCap                    sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_mori_LeftPostIntCap-35.vtk            126           448          322  71.875000
# 59  sub-bbc106         wls_fsl  RightPostIntCap                  sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_mori_RightPostIntCap-123.vtk            187           410          223  54.390244
# 60  sub-bbc108     ols_dipy_mf   LeftPostIntCap           sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_medfilt_mori_LeftPostIntCap-35.vtk            206           381          175  45.931759
# 61  sub-bbc108     ols_dipy_mf  RightPostIntCap         sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_medfilt_mori_RightPostIntCap-123.vtk            243           370          127  34.324324
# 62  sub-bbc108        ols_dipy   LeftPostIntCap                   sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_mori_LeftPostIntCap-35.vtk            129           362          233  64.364641
# 63  sub-bbc108        ols_dipy  RightPostIntCap                 sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_mori_RightPostIntCap-123.vtk            134           356          222  62.359551
# 64  sub-bbc108      ols_fsl_mf   LeftPostIntCap            sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            217           383          166  43.342037
# 65  sub-bbc108      ols_fsl_mf  RightPostIntCap          sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            260           370          110  29.729730
# 66  sub-bbc108         ols_fsl   LeftPostIntCap                    sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_mori_LeftPostIntCap-35.vtk            133           360          227  63.055556
# 67  sub-bbc108         ols_fsl  RightPostIntCap            sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_mori_RightPostIntCap-123_ascii.vtk            133           360          227  63.055556
# 68  sub-bbc108         ols_fsl  RightPostIntCap                  sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_mori_RightPostIntCap-123.vtk            155           354          199  56.214689
# 69  sub-bbc108  restore_camino   LeftPostIntCap    sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            217           383          166  43.342037
# 70  sub-bbc108  restore_camino  RightPostIntCap  sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            246           371          125  33.692722
# 71  sub-bbc108             NaN   LeftPostIntCap            sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_mori_LeftPostIntCap-35.vtk            134           364          230  63.186813
# 72  sub-bbc108             NaN  RightPostIntCap          sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_mori_RightPostIntCap-123.vtk            149           353          204  57.790368
# 73  sub-bbc108     wls_dipy_mf   LeftPostIntCap           sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_dipy_tensor_medfilt_mori_LeftPostIntCap-35.vtk            209           382          173  45.287958
# 74  sub-bbc108     wls_dipy_mf  RightPostIntCap         sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_dipy_tensor_medfilt_mori_RightPostIntCap-123.vtk            249           370          121  32.702703
# 75  sub-bbc108        wls_dipy   LeftPostIntCap                   sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_dipy_tensor_mori_LeftPostIntCap-35.vtk            146           362          216  59.668508
# 76  sub-bbc108        wls_dipy  RightPostIntCap                 sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_dipy_tensor_mori_RightPostIntCap-123.vtk            150           355          205  57.746479
# 77  sub-bbc108      wls_fsl_mf   LeftPostIntCap            sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            217           383          166  43.342037
# 78  sub-bbc108      wls_fsl_mf  RightPostIntCap          sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            260           370          110  29.729730
# 79  sub-bbc108         wls_fsl   LeftPostIntCap                    sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_mori_LeftPostIntCap-35.vtk            133           360          227  63.055556
# 80  sub-bbc108         wls_fsl  RightPostIntCap                  sub-bbc108_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_mori_RightPostIntCap-123.vtk            155           354          199  56.214689
# 81  sub-bbc113     ols_dipy_mf   LeftPostIntCap           sub-bbc113_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_medfilt_mori_LeftPostIntCap-35.vtk            109           350          241  68.857143
# 82  sub-bbc113     ols_dipy_mf  RightPostIntCap         sub-bbc113_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_medfilt_mori_RightPostIntCap-123.vtk            212           341          129  37.829912
# 83  sub-bbc113        ols_dipy   LeftPostIntCap                   sub-bbc113_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_mori_LeftPostIntCap-35.vtk             75           330          255  77.272727
# 84  sub-bbc113        ols_dipy  RightPostIntCap                 sub-bbc113_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_mori_RightPostIntCap-123.vtk             84           337          253  75.074184
# 85  sub-bbc113      ols_fsl_mf   LeftPostIntCap            sub-bbc113_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            138           352          214  60.795455
# 86  sub-bbc113      ols_fsl_mf  RightPostIntCap          sub-bbc113_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            207           341          134  39.296188
# 87  sub-bbc113         ols_fsl   LeftPostIntCap                    sub-bbc113_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_mori_LeftPostIntCap-35.vtk             71           333          262  78.678679
# 88  sub-bbc113         ols_fsl  RightPostIntCap                  sub-bbc113_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_fsl_tensor_mori_RightPostIntCap-123.vtk             98           335          237  70.746269
# 89  sub-bbc113  restore_camino   LeftPostIntCap    sub-bbc113_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            139           347          208  59.942363
# 90  sub-bbc113  restore_camino  RightPostIntCap  sub-bbc113_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            197           341          144  42.228739

# %%
vtk_fbs['%arrived'] = vtk_fbs['total_num_FB'].sub(vtk_fbs['FB_reach_dest']).div(vtk_fbs['total_num_FB']) * 100

# %%
testf = fs / 'bbc' / 'vtk_df_test.csv'
testVTK_DF = pd.read_csv(testf)
testVTK_DF['subjectid'][0][0:10]
# Out:
# 'sub-bbc101'

# %%
testVTK_DF.ix[6:, ['subjectid', 'icountgood', 'icounttotal', 'icounttotal' - 'icountgood', 'length']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-805b3831ee93> in <module>()
# ----> 1 testVTK_DF.ix[6:, ['subjectid', 'icountgood', 'icounttotal', 'icounttotal' - 'icountgood', 'length']]
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
for i, row in testVTK_DF.iterrows():
    print i, row[0][0:10]
    #testVTK_DF.insert(1, 'SUBJID', row[0][0:10], allow_duplicates=True)
#testVTK_DF['SUBJID', 'subjectid']
# Out:
# 0 sub-bbc101
# 1 sub-bbc101
# 2 sub-bbc105
# 3 sub-bbc105
# 4 sub-bbc116
# 5 sub-bbc106
# 6 sub-bbc116
# 7 sub-bbc116
# 8 sub-bbc118

# %%
#selects methods
#testVTK_DF['subjectid'].str[61:88]
#testVTK_DF.loc[:, 'subjectid'].str[61:88]
testVTK_DF['vtk_file_name'].str[61:90]
# Out:
# 0    ols_dipy_tensor_medfilt_mori_
# 1    restore_cam2fsl_tensor_medfil
# 2    restore_cam2fsl_tensor_medfil
# 3    wls_fsl_tensor_medfilt_mori_L
# 4    wls_cam_tensor_medfilt_mori_C
# 5       wls_cam_tensor_mori_CC.vtk
# 6    wls_fsl_tensor_medfilt_mori_L
# 7    wls_fsl_tensor_medfilt_mori_R
# 8    restore_cam2fsl_tensor_medfil
# Name: vtk_file_name, dtype: object

# %%
#selects subj id 
#testVTK_DF['Subjid'] = testVTK_DF['subjectid'].str[0:10]

testVTK_DF.ix[:,['Subjid', 'fit_method', 'vtk_file_name', 'FB_reach_dest', 'total_num_FB']]
# Out:
#        Subjid      fit_method                                                                                                             vtk_file_name  FB_reach_dest  total_num_FB
# 0  sub-bbc101                           sub-bbc101_ses-2_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_medfilt_mori_LeftPostIntCap-35.vtk              0           344
# 1  sub-bbc101  restore_camino  sub-bbc101_ses-2_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk             20           245
# 2  sub-bbc105  restore_camino  sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            350           397
# 3  sub-bbc105      wls_fsl_mf            sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            203           415
# 4  sub-bbc116                                           sub-bbc116_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_cam_tensor_medfilt_mori_CC.vtk           1607          2434
# 5  sub-bbc106                                                   sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_cam_tensor_mori_CC.vtk           2413          3571
# 6  sub-bbc116      wls_fsl_mf            sub-bbc116_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            130           313
# 7  sub-bbc116      wls_fsl_mf          sub-bbc116_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk             15           101
# 8  sub-bbc118  restore_camino  sub-bbc118_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            135           315

# %%
#this renames col label 'subjectid' with 'vtk_file_name'
testVTK_DF.rename(columns={'subjectid': 'vtk_file_name', 'icountgood': 'FB_reach_dest', 'icounttotal': 'total_num_FB'}, inplace=True)

# %%
testVTK_DF.ix[:,['Subjid', 'fit_method', 'region', 'vtk_file_name', 'FB_reach_dest', 'total_num_FB']]
# Out:
#        Subjid      fit_method           region                                                                                                             vtk_file_name  FB_reach_dest  total_num_FB
# 0  sub-bbc101     ols_dipy_mf   LeftPostIntCap           sub-bbc101_ses-2_dti_15dir_b1000_1_eddy_corrected_repol_std2_ols_dipy_tensor_medfilt_mori_LeftPostIntCap-35.vtk              0           344
# 1  sub-bbc101  restore_camino  RightPostIntCap  sub-bbc101_ses-2_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk             20           245
# 2  sub-bbc105  restore_camino  RightPostIntCap  sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            350           397
# 3  sub-bbc105      wls_fsl_mf   LeftPostIntCap            sub-bbc105_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            203           415
# 4  sub-bbc116   wls_camino_mf  Corpus_Callosum                           sub-bbc116_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_cam_tensor_medfilt_mori_CC.vtk           1607          2434
# 5  sub-bbc106      wls_camino  Corpus_Callosum                                   sub-bbc106_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_cam_tensor_mori_CC.vtk           2413          3571
# 6  sub-bbc116      wls_fsl_mf   LeftPostIntCap            sub-bbc116_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_medfilt_mori_LeftPostIntCap-35.vtk            130           313
# 7  sub-bbc116      wls_fsl_mf  RightPostIntCap          sub-bbc116_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_wls_fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk             15           101
# 8  sub-bbc118  restore_camino  RightPostIntCap  sub-bbc118_ses-1_dti_15dir_b1000_1_eddy_corrected_repol_std2_restore_cam2fsl_tensor_medfilt_mori_RightPostIntCap-123.vtk            135           315

# %%
#this renames col label 'subjectid' with 'vtk_file_name'
testVTK_DF.rename(columns={'subjectid': 'vtk_file_name', 'icountgood': 'FB_reach_dest', 'icounttotal': 'total_num_FB'}, inplace=True)
#makes subj id fm 1st 10 chars of vtk_file_name
testVTK_DF['Subjid'] = testVTK_DF['vtk_file_name'].str[0:10]
#makes fit methods
testVTK_DF.loc[testVTK_DF['vtk_file_name'].str.contains('restore_cam2fsl_tensor_medf'), 'fit_method'] = 'restore_camino'
testVTK_DF.loc[testVTK_DF['vtk_file_name'].str.contains('wls_fsl_tensor_medf'), 'fit_method'] = 'wls_fsl_mf'
testVTK_DF.loc[testVTK_DF['vtk_file_name'].str.contains('ols_dipy_tensor_med'), 'fit_method'] = 'ols_dipy_mf'
testVTK_DF.loc[testVTK_DF['vtk_file_name'].str.contains('wls_cam_tensor_medf'), 'fit_method'] = 'wls_camino_mf'
testVTK_DF.loc[testVTK_DF['vtk_file_name'].str.contains('wls_cam_tensor_mori'), 'fit_method'] = 'wls_camino'
#makes region names for regions col.
testVTK_DF.loc[testVTK_DF['vtk_file_name'].str.contains('LeftPostIntCap'), 'region'] = 'LeftPostIntCap'
testVTK_DF.loc[testVTK_DF['vtk_file_name'].str.contains('RightPostIntCap'), 'region'] = 'RightPostIntCap'
testVTK_DF.loc[testVTK_DF['vtk_file_name'].str.contains('mori_CC'), 'region'] = 'Corpus_Callosum'
